# %% [markdown]
# ### Defination
# the map() function applies a given function to all items in an input list(or any other iterable) and returns a map object(iterator).
# Particularly used for transforming data in a list comprehensively
