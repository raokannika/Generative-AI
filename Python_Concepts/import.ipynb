# %% [markdown]
# modules and pacakges help organize and reuse code.
# to import any package then write import pacakage_name

# %%
import math # this is a package which has alot of inbuilt functions for math operations

# %%
from math import sqrt, pi # this is a way to import specific functions from the math package
print(sqrt(16)) # this will print the square root of 16
print(pi) # this will print the value of pi
# Out:
# 4.0
# 3.141592653589793

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
from math import * # this is a way to import all functions from the math package
