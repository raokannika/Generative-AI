# %% [markdown]
# ### Example 1: Manage A To Do List
# Create a To Do list to keep track of tasks

# %%
to_do_list=["GenAi","DSA","System Engineering"]
print(to_do_list)
## Adding more task
to_do_list.append("Business Intelligence")
to_do_list.append("Dance")

print(to_do_list)
## Removeing after completion of task

to_do_list.remove("GenAi")

##Checking if a task is in the list
if "Dance" in to_do_list:
    print("Don't to forget to dance")

print("To do list remaining")
for task in to_do_list:
    print(f"-{task}")
# Out:
# ['GenAi', 'DSA', 'System Engineering']
# ['GenAi', 'DSA', 'System Engineering', 'Business Intelligence', 'Dance']
# Don't to forget to dance
# To do list remaining
# -DSA
# -System Engineering
# -Business Intelligence
# -Dance

# %% [markdown]
# ### Example 2: Organizing Student Grades
# Create a list to store and calculate average grades for students

# %%
grades = [85, 92, 78, 90, 88]

# Adding new grade 
grades.append(95)

#Calculating the average grade 
average_grade = sum(grades)/len(grades)
print(f"Average Grade {average_grade: .2f}")

#Finding the highest and lowest grade

highest_grade = max(grades)
lowest_grade = min(grades)
print(f"Highest Grade: {highest_grade}\nLowest Garde: {lowest_grade}")
# Out:
# Average Grade  88.00
# Highest Grade: 95
# Lowest Garde: 78

# %% [markdown]
# ### Managing an inventory
# Use a list to manage inventory items in a store

# %%
inventory = ["Apples","Orange", "Banana","Strawberries","Cucumber"]
print(inventory)

# Adding new items
inventory.append("Grapes")
print(inventory)

# Removing an item that is not in stock
inventory.remove("Banana")
print(inventory)

# Checking if an item is in stock
item="Orange"
if item in inventory:
    print(f"{item} is in stock!!")
else :
    print(f"{item} is not in stock!!")

# Printing Inventory list
print("Inventory List: ")
for item in inventory:
    print(f"-{item}")
# Out:
# ['Apples', 'Orange', 'Banana', 'Strawberries', 'Cucumber']
# ['Apples', 'Orange', 'Banana', 'Strawberries', 'Cucumber', 'Grapes']
# ['Apples', 'Orange', 'Strawberries', 'Cucumber', 'Grapes']
# Orange is in stock!!
# Inventory List:
# -Apples
# -Orange
# -Strawberries
# -Cucumber
# -Grapes

# %% [markdown]
# ### Example 4: Collecting User Feedback
# Use a list to collect and analyze user feedback
